# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
import re

# %%
AllData = pd.read_csv('AllData.csv')

# %%
CaucusFiltered = pd.read_csv('CaucusFilter.csv')

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_text(text):
    text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)

    tokens = word_tokenize(text)

    tokens = [word.lower() for word in tokens]

    tokens = [word for word in tokens if word.isalpha()]

    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if not word in stop_words]

    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    return ' '.join(tokens)

AllData['Proccessed Press Release'] = AllData['Press Release'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/aaryakagalwala/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/aaryakagalwala/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/aaryakagalwala/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
CaucusFiltered['Proccessed Press Release'] = CaucusFiltered['Press Release'].apply(preprocess_text)

# %%
AllData.to_csv('CleanedData.csv',index=False)
CaucusFiltered.to_csv('CleanedCaucus.csv',index=False)

# %%
CaucusFiltered
# Out:
#          Date           Member Party State / District  \
# 0       May 8  Morgan Griffith     R            Va.-9
# 1       May 8  Ayanna Pressley     D          Mass.-7
# 2       May 8  Pramila Jayapal     D          Wash.-7
# 3       May 3       Andy Biggs     R          Ariz.-5
# 4       May 6   Julia Brownley     D        Calif.-26
# ..        ...              ...   ...              ...
# 179  April 11       Mike Levin     D        Calif.-49
# 180  April 12       Mike Levin     D        Calif.-49
# 181  April 12       Mike Levin     D        Calif.-49
# 182  April 11    Jared Huffman     D         Calif.-2
# 183  April 12    Jared Huffman     D         Calif.-2
#
#                                                  Title  \
# 0    Griffith Statement on President Biden Pause on...
# 1    Pressley, Haiti Caucus, Colleagues, Advocates ...
# 2    Jayapal, Padilla, Congressional Leaders, Advoc...
# 3    Opposing the Uniparty's Latest Attack on the C...
# 4    Brownley Introduces Legislation to Expand Acce...
# ..                                                 ...
# 179  SEEC Clean Energy Deployment Task Force Co-Cha...
# 180  Rep. Levin and House Natural Resources Committ...
# 181  Rep. Mike Levin and San Diego Congressional De...
# 182  Rep. Huffman Statement on 2024 Salmon Season C...
# 183  Huffman, Committee Democrats Applaud Biden Adm...
#
#                                          Press Release  \
# 0    Washington, DC – Today, Democratic Leader Hake...
# 1    Washington, DC – Today, Congresswoman Julia Br...
# 2    April 23, 2024 Text of Letter (PDF) WASHINGTON...
# 3                In advance of chairing a congressi...
# 4    Welcome to the on-line office for Congressman ...
# ..                                                 ...
# 179  \nReference ID: 18.d83a2217.1715273339.7623682...
# 180  \nReference ID: 18.d83a2217.1715273339.7623c7a...
# 181  \nReference ID: 18.d83a2217.1715273339.762408d...
# 182  \nReference ID: 18.d83a2217.1715273340.7625986...
# 183  \nReference ID: 18.d83a2217.1715273340.7626d02...
#
#                      Caucus                           Proccessed Press Release
# 0             Freedom Party  washington dc today democratic leader hakeem j...
# 1      Congress Progressive  washington dc today congresswoman julia brownl...
# 2      Congress Progressive  april text letter pdf washington haiti caucus ...
# 3             Freedom Party  advance chairing congressional hearing tuesday...
# 4    New Democrat Coalition  welcome office congressman gregorio kilili cam...
# ..                      ...                                                ...
# 179    Congress Progressive  reference id proceed problem persists please c...
# 180    Congress Progressive  reference id proceed problem persists please c...
# 181    Congress Progressive  reference id proceed problem persists please c...
# 182    Congress Progressive  reference id proceed problem persists please c...
# 183    Congress Progressive  reference id proceed problem persists please c...
#
# [184 rows x 8 columns]

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
def tokenize_by_sentence(text):
    doc = nlp(text)
    sentences = [sent.text for sent in doc.sents]
    return sentences

CaucusFiltered['sentences'] = CaucusFiltered['Processed Press Release'].apply(tokenize_by_sentence)
Caucus_sentences = CaucusFiltered.explode('sentences')
Caucus_sentences['sentence_index'] = Caucus_setences.groupby(level=0).cumcount()
Caucus_sentences.reset_index(drop=True,inplace=True)

disputed = AllData_sentences[AllData_sentences['target']=='dispt']
sentence_df = sentence_df[sentence_df['target']!='dispt']

sentence_df
